# %%
#Importing the library
import pandas as pd
import numpy as np
import requests
import selenium
from selenium import webdriver
from bs4 import BeautifulSoup
#importing the Web driver
dr=webdriver.Chrome("chromedriver111.exe")
import time

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import re

# %%
url="https://www.yatra.com/"

# %%
dr.get(url)

# %%
search_btn = dr.find_element_by_xpath('//input[@type="submit"]').click()

# %%
nov=dr.find_element_by_xpath('//div[@class="month-cal"]')
nov
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="cd42738dcb9669b770d48de58b6e05de", element="36edccf8-356d-47fd-ac5f-9bfe91c52873")>

# %%
date_att1=[]
date1=dr.find_elements_by_xpath('//div[@class="date-holder"]')

# %%
for i in date1:
        date_att1.append(i.get_attribute('href'))

# %%
len(date_att1)
# Out:
# 30

# %%
for i in date_att1:
    for i in dr.find_elements_by_xpath('//div[@class="fs-13 airline-name no-pad col-8"]'):
      h1.append(i.text)

# %%
h1=[]

# %%
h1
# Out:
# ['Air Asia\nI5-735/334',
#  'Air Asia\nI5-735/941',
#  'Air Asia\nI5-721/334',
#  'Air Asia\nI5-721/941',
#  'Air Asia\nI5-1529/1561',
#  'Air Asia\nI5-747/334',
#  'Air Asia\nI5-740/1561',
#  'Air Asia\nI5-747/941',
#  'Air Asia\nI5-788/942',
#  'Go First\nG8-530',
#  'Go First\nG8-334',
#  'Go First\nG8-354',
#  'Go First\nG8-2501',
#  'Go First\nG8-336',
#  'Go First\nG8-346',
#  'Go First\nG8-330',
#  'Go First\nG8-338',
#  'Go First\nG8-392',
#  'Go First\nG8-323',
#  'Vistara\nUK-975',
#  'Air India\nAI-887',
#  'IndiGo\n6E-2054',
#  'IndiGo\n6E-5001',
#  'Air India\nAI-665',
#  'IndiGo\n6E-5329',
#  'Air Asia\nI5-735/334',
#  'Air Asia\nI5-735/941',
#  'Air Asia\nI5-721/334',
#  'Air Asia\nI5-721/941',
#  'Air Asia\nI5-1529/1561',
#  'Air Asia\nI5-747/334',
#  'Air Asia\nI5-740/1561',
#  'Air Asia\nI5-747/941',
#  'Air Asia\nI5-788/942',
#  'Go First\nG8-530',
#  'Go First\nG8-334',
#  'Go First\nG8-354',
#  'Go First\nG8-2501',
#  'Go First\nG8-336',
#  'Go First\nG8-346',
# ...

# %%
len(h1)
# Out:
# 750

# %%
h2=[]

for i in date_att1:
    for i in dr.find_elements_by_xpath('//div[@class="i-b pr"]'):
      h2.append(i.text)

# %%
h2
# Out:
# ['21:25',
#  '21:25',
#  '20:45',
#  '20:45',
#  '09:35',
#  '18:35',
#  '08:00',
#  '18:35',
#  '22:10',
#  '07:00',
#  '08:00',
#  '22:30',
#  '02:40',
#  '14:20',
#  '19:40',
#  '21:00',
#  '10:30',
#  '15:00',
#  '17:55',
#  '06:00',
#  '07:00',
#  '06:30',
#  '07:15',
#  '08:00',
#  '08:10',
#  '21:25',
#  '21:25',
#  '20:45',
#  '20:45',
#  '09:35',
#  '18:35',
#  '08:00',
#  '18:35',
#  '22:10',
#  '07:00',
#  '08:00',
#  '22:30',
#  '02:40',
#  '14:20',
#  '19:40',
#  '21:00',
#  '10:30',
#  '15:00',
#  '17:55',
#  '06:00',
#  '07:00',
#  '06:30',
#  '07:15',
#  '08:00',
#  '08:10',
#  '21:25',
#  '21:25',
#  '20:45',
#  '20:45',
#  '09:35',
#  '18:35',
#  '08:00',
#  '18:35',
#  '22:10',
#  '07:00',
#  '08:00',
#  '22:30',
#  '02:40',
#  '14:20',
#  '19:40',
#  '21:00',
#  '10:30',
#  '15:00',
#  '17:55',
#  '06:00',
#  '07:00',
#  '06:30',
#  '07:15',
#  '08:00',
#  '08:10',
#  '21:25',
#  '21:25',
#  '20:45',
#  '20:45',
#  '09:35',
#  '18:35',
#  '08:00',
#  '18:35',
# ...

# %%
len(h2)
# Out:
# 750

# %%
h3=[]

for i in date_att1:
    for i in dr.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
      h3.append(i.text)

# %%
h3
# Out:
# ['20:15',
#  '16:00',
#  '20:15',
#  '06:20\n+ 1 day',
#  '06:20\n+ 1 day',
#  '20:45',
#  '11:05',
#  '08:20',
#  '22:35',
#  '23:35',
#  '00:50\n+ 1 day',
#  '22:25',
#  '13:00',
#  '15:40',
#  '21:05',
#  '19:20',
#  '14:55',
#  '15:45',
#  '22:45',
#  '15:40',
#  '08:00',
#  '20:40',
#  '09:05',
#  '07:10',
#  '08:20',
#  '20:15',
#  '16:00',
#  '20:15',
#  '06:20\n+ 1 day',
#  '06:20\n+ 1 day',
#  '20:45',
#  '11:05',
#  '08:20',
#  '22:35',
#  '23:35',
#  '00:50\n+ 1 day',
#  '22:25',
#  '13:00',
#  '15:40',
#  '21:05',
#  '19:20',
#  '14:55',
#  '15:45',
#  '22:45',
#  '15:40',
#  '08:00',
#  '20:40',
#  '09:05',
#  '07:10',
#  '08:20',
#  '20:15',
#  '16:00',
#  '20:15',
#  '06:20\n+ 1 day',
#  '06:20\n+ 1 day',
#  '20:45',
#  '11:05',
#  '08:20',
#  '22:35',
#  '23:35',
#  '00:50\n+ 1 day',
#  '22:25',
#  '13:00',
#  '15:40',
#  '21:05',
#  '19:20',
#  '14:55',
#  '15:45',
#  '22:45',
#  '15:40',
#  '08:00',
#  '20:40',
#  '09:05',
#  '07:10',
#  '08:20',
#  '20:15',
# ...

# %%
len(h3)
# Out:
# 750

# %%
h4=[]

for i in date_att1:
    for i in dr.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
      h4.append(i.text)

# %%
h4
# Out:
# ['5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
# ...

# %%
len(h4)
# Out:
# 750

# %%
h5=[]

for i in date_att1:
    for i in dr.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
      h5.append(i.text)

# %%
h5
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
# ...

# %%
len(h5)
# Out:
# 750

# %%
h6=[]

for i in date_att1:
    for i in dr.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
      h6.append(i.text)

# %%
h6
# Out:
# ['5h 35m',
#  '6h 35m',
#  '7h 35m',
#  '11h 40m',
#  '14h 05m',
#  '1h 55m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '4h 40m',
#  '4h 50m',
#  '5h 00m',
#  '5h 35m',
#  '5h 50m',
#  '6h 45m',
#  '6h 55m',
#  '7h 15m',
#  '7h 30m',
#  '2h 00m',
#  '2h 00m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '5h 35m',
#  '6h 35m',
#  '7h 35m',
#  '11h 40m',
#  '14h 05m',
#  '1h 55m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '4h 40m',
#  '4h 50m',
#  '5h 00m',
#  '5h 35m',
#  '5h 50m',
#  '6h 45m',
#  '6h 55m',
#  '7h 15m',
#  '7h 30m',
#  '2h 00m',
#  '2h 00m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '5h 35m',
#  '6h 35m',
#  '7h 35m',
#  '11h 40m',
#  '14h 05m',
#  '1h 55m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '4h 40m',
#  '4h 50m',
#  '5h 00m',
#  '5h 35m',
#  '5h 50m',
#  '6h 45m',
#  '6h 55m',
#  '7h 15m',
#  '7h 30m',
#  '2h 00m',
#  '2h 00m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '5h 35m',
# ...

# %%
len(h6)
# Out:
# 750

# %%
len(date_att1)
# Out:
# 30

# %%
h9=[]

# %%
for i in date_att1:
    for i in dr.find_elements_by_xpath('//div[@class="date-holder"]'):
      h9.append(i.text.replace('\n','Nov'))

# %%
h9
# Out:
# ['1Nov5,953',
#  '2Nov5,953',
#  '3Nov5,953',
#  '4Nov5,953',
#  '5Nov4,931',
#  '6Nov4,931',
#  '7Nov5,954',
#  '8Nov5,954',
#  '9Nov4,931',
#  '10Nov4,931',
#  '11Nov4,931',
#  '12Nov4,931',
#  '13Nov4,931',
#  '14Nov5,953',
#  '15Nov4,931',
#  '16Nov4,931',
#  '17Nov4,931',
#  '18Nov4,931',
#  '19Nov4,931',
#  '20Nov5,954',
#  '21Nov2,456',
#  '22Nov2,456',
#  '23Nov2,456',
#  '24Nov2,456',
#  '25Nov2,456',
#  '26Nov2,456',
#  '27Nov2,456',
#  '28Nov2,456',
#  '29Nov2,456',
#  '30Nov2,352',
#  '1Nov5,953',
#  '2Nov5,953',
#  '3Nov5,953',
#  '4Nov5,953',
#  '5Nov4,931',
#  '6Nov4,931',
#  '7Nov5,954',
#  '8Nov5,954',
#  '9Nov4,931',
#  '10Nov4,931',
#  '11Nov4,931',
#  '12Nov4,931',
#  '13Nov4,931',
#  '14Nov5,953',
#  '15Nov4,931',
#  '16Nov4,931',
#  '17Nov4,931',
#  '18Nov4,931',
#  '19Nov4,931',
#  '20Nov5,954',
#  '21Nov2,456',
#  '22Nov2,456',
#  '23Nov2,456',
#  '24Nov2,456',
#  '25Nov2,456',
#  '26Nov2,456',
#  '27Nov2,456',
#  '28Nov2,456',
#  '29Nov2,456',
# ...

# %%
len(h9)
# Out:
# 900

# %%
url="https://www.yatra.com/"

# %%
dr.get(url)

# %%
search_btn = dr.find_element_by_xpath('//input[@type="submit"]').click()

# %%
step1=dr.find_element_by_xpath('//div[@class="next fs-12 cursor-pointer font-lightgrey"]').click()

# %%
step2=dr.find_element_by_xpath('//div[@class="next fs-12 cursor-pointer font-lightgrey"]').click()

# %%
dec=dr.find_element_by_xpath('//div[@class="month-cal"]')
dec
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="bea9c8b2b5992f8254e7205896808dab", element="97af4547-24dd-4235-848e-ac617a9e6153")>

# %%
date=[]
date2=dr.find_elements_by_xpath('//ul[@class="full-width no-wrap ovf-hidden"]/li')

# %%
len(date2)
# Out:
# 21

# %%
s1=[]

# %%
for i in date2:
 for i in dr.find_elements_by_xpath('//span[@class="i-b text ellipsis"]'):
    s1.append(i.text)

# %%
s1
# Out:
# ['Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
# ...

# %%
len(s1)
# Out:
# 525

# %%
s2=[]

for i in date2:
    for i in dr.find_elements_by_xpath('//div[@class="i-b pr"]'):
      s2.append(i.text)

# %%
s2
# Out:
# ['04:25',
#  '07:00',
#  '08:00',
#  '02:40',
#  '05:30',
#  '06:30',
#  '06:30',
#  '06:25',
#  '05:20',
#  '22:10',
#  '23:25',
#  '21:20',
#  '20:15',
#  '15:05',
#  '17:50',
#  '06:00',
#  '20:00',
#  '07:20',
#  '18:50',
#  '19:40',
#  '21:00',
#  '10:30',
#  '07:00',
#  '02:30',
#  '08:00',
#  '04:25',
#  '07:00',
#  '08:00',
#  '02:40',
#  '05:30',
#  '06:30',
#  '06:30',
#  '06:25',
#  '05:20',
#  '22:10',
#  '23:25',
#  '21:20',
#  '20:15',
#  '15:05',
#  '17:50',
#  '06:00',
#  '20:00',
#  '07:20',
#  '18:50',
#  '19:40',
#  '21:00',
#  '10:30',
#  '07:00',
#  '02:30',
#  '08:00',
#  '04:25',
#  '07:00',
#  '08:00',
#  '02:40',
#  '05:30',
#  '06:30',
#  '06:30',
#  '06:25',
#  '05:20',
#  '22:10',
#  '23:25',
#  '21:20',
#  '20:15',
#  '15:05',
#  '17:50',
#  '06:00',
#  '20:00',
#  '07:20',
#  '18:50',
#  '19:40',
#  '21:00',
#  '10:30',
#  '07:00',
#  '02:30',
#  '08:00',
#  '04:25',
#  '07:00',
#  '08:00',
#  '02:40',
#  '05:30',
#  '06:30',
#  '06:30',
#  '06:25',
# ...

# %%
len(s2)
# Out:
# 525

# %%
s3=[]

for i in date2:
    for i in dr.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]'):
      s3.append(i.text)

# %%
s3
# Out:
# ['06:35',
#  '09:10',
#  '10:10',
#  '04:55',
#  '07:50',
#  '08:50',
#  '08:50',
#  '11:05',
#  '11:05',
#  '04:45\n+ 1 day',
#  '07:10\n+ 1 day',
#  '07:10\n+ 1 day',
#  '07:10\n+ 1 day',
#  '18:15',
#  '21:35',
#  '08:00',
#  '22:15',
#  '09:35',
#  '21:05',
#  '21:55',
#  '23:15',
#  '12:50',
#  '09:05',
#  '04:40',
#  '10:10',
#  '06:35',
#  '09:10',
#  '10:10',
#  '04:55',
#  '07:50',
#  '08:50',
#  '08:50',
#  '11:05',
#  '11:05',
#  '04:45\n+ 1 day',
#  '07:10\n+ 1 day',
#  '07:10\n+ 1 day',
#  '07:10\n+ 1 day',
#  '18:15',
#  '21:35',
#  '08:00',
#  '22:15',
#  '09:35',
#  '21:05',
#  '21:55',
#  '23:15',
#  '12:50',
#  '09:05',
#  '04:40',
#  '10:10',
#  '06:35',
#  '09:10',
#  '10:10',
#  '04:55',
#  '07:50',
#  '08:50',
#  '08:50',
#  '11:05',
#  '11:05',
#  '04:45\n+ 1 day',
#  '07:10\n+ 1 day',
#  '07:10\n+ 1 day',
#  '07:10\n+ 1 day',
#  '18:15',
#  '21:35',
#  '08:00',
#  '22:15',
#  '09:35',
#  '21:05',
#  '21:55',
#  '23:15',
#  '12:50',
#  '09:05',
#  '04:40',
# ...

# %%
len(s3)
# Out:
# 525

# %%
s4=[]

for i in date2:
    for i in dr.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]'):
      s4.append(i.text)
    
    
s4
# Out:
# ['2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,476',
#  '2,476',
#  '2,556',
#  '2,757',
#  '2,772',
#  '2,772',
#  '2,790',
#  '2,790',
#  '2,790',
#  '2,791',
#  '2,791',
#  '2,791',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,476',
#  '2,476',
#  '2,556',
#  '2,757',
#  '2,772',
#  '2,772',
#  '2,790',
#  '2,790',
#  '2,790',
#  '2,791',
#  '2,791',
#  '2,791',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,476',
#  '2,476',
#  '2,556',
#  '2,757',
#  '2,772',
#  '2,772',
#  '2,790',
#  '2,790',
#  '2,790',
#  '2,791',
#  '2,791',
#  '2,791',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
#  '2,456',
# ...

# %%
s5=[]

for i in date2:
    for i in dr.find_elements_by_xpath('//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]'):
      s5.append(i.text)

# %%
s5
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
# ...

# %%
s6=[]

for i in date_att1:
    for i in dr.find_elements_by_xpath('//p[@class="fs-12 bold du mb-2"]'):
      s6.append(i.text)
s6
# Out:
# ['2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '4h 40m',
#  '5h 45m',
#  '6h 35m',
#  '7h 45m',
#  '9h 50m',
#  '10h 55m',
#  '3h 10m',
#  '3h 45m',
#  '2h 00m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '4h 40m',
#  '5h 45m',
#  '6h 35m',
#  '7h 45m',
#  '9h 50m',
#  '10h 55m',
#  '3h 10m',
#  '3h 45m',
#  '2h 00m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '4h 40m',
#  '5h 45m',
#  '6h 35m',
#  '7h 45m',
#  '9h 50m',
#  '10h 55m',
#  '3h 10m',
#  '3h 45m',
#  '2h 00m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
# ...

# %%
H1=s1+h1
H2=s2+h2
H3=s3+h3
H4=s4+h4
H5=s5+h5
H6=s6+h6

# %%
s9=[]

# %%
for i in date2:
    for i in dr.find_elements_by_xpath('//div[@class="date-holder"]'):
      s9.append(i.text.replace('\n','Dec'))

# %%
s9
# Out:
# ['1Dec2,456',
#  '2Dec2,456',
#  '3Dec2,456',
#  '4Dec2,352',
#  '5Dec2,456',
#  '6Dec2,456',
#  '7Dec2,456',
#  '8Dec2,456',
#  '9Dec2,456',
#  '10Dec2,456',
#  '11Dec2,456',
#  '12Dec2,476',
#  '13Dec2,352',
#  '14Dec2,352',
#  '15Dec2,456',
#  '16Dec2,456',
#  '17Dec2,456',
#  '18Dec2,456',
#  '19Dec2,456',
#  '20Dec2,456',
#  '21Dec2,456',
#  '22Dec2,456',
#  '23Dec2,456',
#  '24Dec2,352',
#  '25Dec2,456',
#  '26Dec2,476',
#  '27Dec2,456',
#  '28Dec2,456',
#  '29Dec2,456',
#  '30Dec2,456',
#  '31Dec2,456',
#  '1Dec2,456',
#  '2Dec2,456',
#  '3Dec2,456',
#  '4Dec2,352',
#  '5Dec2,456',
#  '6Dec2,456',
#  '7Dec2,456',
#  '8Dec2,456',
#  '9Dec2,456',
#  '10Dec2,456',
#  '11Dec2,456',
#  '12Dec2,476',
#  '13Dec2,352',
#  '14Dec2,352',
#  '15Dec2,456',
#  '16Dec2,456',
#  '17Dec2,456',
#  '18Dec2,456',
#  '19Dec2,456',
#  '20Dec2,456',
#  '21Dec2,456',
#  '22Dec2,456',
#  '23Dec2,456',
#  '24Dec2,352',
#  '25Dec2,456',
#  '26Dec2,476',
#  '27Dec2,456',
#  '28Dec2,456',
# ...

# %%
H9=h9+s9

# %%
print (len(H1),len(H2),len(H3),len(H4),len(H5),len(H6))
# Out:
# 1275 1275 1275 1275 1275 1500

# %%
data=pd.DataFrame({})

# %%
data['FlightNAME']=H1[:1275]
data['Date']=H9[:1275]
data['Arr_timr']=H2[:1275]
data['dep_time']=H3[:1275]
data['Fare']=H4[:1275]
data['Stop']=H5[:1275]
data['Time']=H6[:1275]

# %%
data
# Out:
#              FlightNAME        Date Arr_timr dep_time   Fare      Stop    Time
# 0              Air Asia   1Nov5,953    04:25    06:35  2,456  Non Stop  2h 10m
# 1              Go First   2Nov5,953    07:00    09:10  2,456  Non Stop  2h 10m
# 2              Go First   3Nov5,953    08:00    10:10  2,456  Non Stop  2h 10m
# 3              Go First   4Nov5,953    02:40    04:55  2,456  Non Stop  2h 15m
# 4                IndiGo   5Nov4,931    05:30    07:50  2,456  Non Stop  2h 20m
# ...                 ...         ...      ...      ...    ...       ...     ...
# 1270    Vistara\nUK-975  30Dec2,456    06:00    08:00  5,955  Non Stop  2h 00m
# 1271   SpiceJet\nSG-611  31Dec2,456    18:40    20:40  5,955  Non Stop  2h 00m
# 1272  Air India\nAI-887   1Dec2,456    07:00    09:05  5,955  Non Stop  2h 05m
# 1273    IndiGo\n6E-2576   2Dec2,456    05:00    07:10  5,955  Non Stop  2h 10m
# 1274    IndiGo\n6E-6125   3Dec2,456    06:10    08:20  5,955  Non Stop  2h 10m
#
# [1275 rows x 7 columns]

# %%
data.to_csv('FLIGHTDATA1_csv', index=False)
